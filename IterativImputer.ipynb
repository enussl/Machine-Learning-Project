# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.model_selection import GridSearchCV, cross_validate, cross_val_score, StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, f1_score
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectFromModel
from sklearn.decomposition import PCA
import statsmodels.api as sm
from statsmodels.imputation.mice import MICE, MICEData
from matplotlib import pyplot
from sklearn.model_selection import KFold
from sklearn.preprocessing import LabelEncoder
from sklearn import preprocessing
from sklearn.metrics import confusion_matrix
from sklearn import metrics
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.impute import SimpleImputer
import time
from collections import Counter
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
from sklearn import metrics
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.experimental import enable_iterative_imputer 
from sklearn.impute import IterativeImputer
from sklearn.neural_network import MLPClassifier
import itertools
#import all the functions we wrote ourselves
# %pip install import_ipynb
import import_ipynb
#import Functions as functions
# Out:
# Requirement already satisfied: import_ipynb in c:\users\frede\anaconda3\lib\site-packages (0.1.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
#index_col=0 to make the companies/ the dates the indizes
sp=pd.read_csv("Data/SP500.csv",sep=",",index_col=0)
gdp = pd.read_csv("Data/GDP USA.csv", sep=",", index_col=0)
infl = pd.read_csv("Data/INFL.csv",sep=",", index_col=0)
df14=pd.read_csv("Data/2014_Financial_Data.csv",sep=",",index_col=0)
df15=pd.read_csv("Data/2015_Financial_Data.csv",sep=",",index_col=0)
df16=pd.read_csv("Data/2016_Financial_Data.csv",sep=",",index_col=0)
df17=pd.read_csv("Data/2017_Financial_Data.csv",sep=",",index_col=0)
df18=pd.read_csv("Data/2018_Financial_Data.csv",sep=",",index_col=0)

# %%
#combining the datasets with an outer join to make a huge df

df=pd.concat([df14,df15,df16,df17,df18])
df.shape
df
# Out:
#            Revenue  Revenue Growth  Cost of Revenue  Gross Profit  \
# PG    7.440100e+10         -0.0713     3.903000e+10  3.537100e+10
# VIPS  3.734148e+09          1.1737     2.805625e+09  9.285226e+08
# KR    9.837500e+10          0.0182     7.813800e+10  2.023700e+10
# RAD   2.552641e+10          0.0053     1.820268e+10  7.323734e+09
# GIS   1.790960e+10          0.0076     1.153980e+10  6.369800e+09
# ...            ...             ...              ...           ...
# YRIV  0.000000e+00          0.0000     0.000000e+00  0.000000e+00
# YTEN  5.560000e+05         -0.4110     0.000000e+00  5.560000e+05
# ZKIN  5.488438e+07          0.2210     3.659379e+07  1.829059e+07
# ZOM   0.000000e+00          0.0000     0.000000e+00  0.000000e+00
# ZYME  5.301900e+07          0.0243     0.000000e+00  5.301900e+07
#
#       R&D Expenses  SG&A Expense  Operating Expenses  Operating Income  \
# PG    0.000000e+00  2.146100e+10        2.146100e+10      1.391000e+10
# VIPS  1.083303e+08  3.441414e+08        7.939267e+08      1.345959e+08
# KR    0.000000e+00  1.519600e+10        1.751200e+10      2.725000e+09
# RAD   0.000000e+00  6.561162e+09        6.586482e+09      7.372520e+08
# GIS   0.000000e+00  3.474300e+09        3.412400e+09      2.957400e+09
# ...            ...           ...                 ...               ...
# YRIV  0.000000e+00  3.755251e+06        3.755251e+06     -3.755251e+06
# YTEN  4.759000e+06  5.071000e+06        9.830000e+06     -9.274000e+06
# ZKIN  1.652633e+06  7.020320e+06        8.672953e+06      9.617636e+06
# ZOM   1.031715e+07  4.521349e+06        1.664863e+07     -1.664863e+07
# ZYME  5.668400e+07  2.945700e+07        8.614600e+07     -3.312700e+07
#
#       Interest Expense  Earnings before Tax  ...  Debt Growth  \
# PG        7.090000e+08         1.449400e+10  ...       0.1228
# VIPS      1.214869e+07         1.753823e+08  ...          NaN
# KR        4.430000e+08         2.270000e+09  ...       0.2738
# RAD       4.245910e+08         2.502180e+08  ...      -0.0458
# GIS       3.024000e+08         2.707700e+09  ...       0.1025
# ...                ...                  ...  ...          ...
# YRIV      1.105849e+07        -1.482451e+07  ...      -0.0152
# YTEN      0.000000e+00        -9.170000e+06  ...       0.0000
# ZKIN      1.239170e+06         8.416324e+06  ...      -0.0968
# ZOM       0.000000e+00        -1.664769e+07  ...       0.0000
# ZYME      1.660000e+05        -3.438500e+07  ...       0.0000
#
#       R&D Expense Growth  SG&A Expenses Growth              Sector  \
# PG                0.0000               -0.1746  Consumer Defensive
# VIPS              1.6484                1.7313  Consumer Defensive
# KR                0.0000                0.0234  Consumer Defensive
# RAD               0.0000               -0.0060  Consumer Defensive
# GIS               0.0000               -0.0220  Consumer Defensive
# ...                  ...                   ...                 ...
# YRIV              0.0000               -0.2602         Real Estate
# YTEN              0.0352               -0.0993     Basic Materials
# ZKIN              0.2415                0.8987     Basic Materials
# ZOM               2.7499                0.1457         Industrials
# ZYME              0.3577                0.5880          Healthcare
#
#       2015 PRICE VAR [%]  Class  2016 PRICE VAR [%]  2017 PRICE VAR [%]  \
# PG             -9.323276      0                 NaN                 NaN
# VIPS          -25.512193      0                 NaN                 NaN
# KR             33.118297      1                 NaN                 NaN
# RAD             2.752291      1                 NaN                 NaN
# GIS            12.897715      1                 NaN                 NaN
# ...                  ...    ...                 ...                 ...
# YRIV                 NaN      0                 NaN                 NaN
# YTEN                 NaN      0                 NaN                 NaN
# ZKIN                 NaN      0                 NaN                 NaN
# ZOM                  NaN      0                 NaN                 NaN
# ZYME                 NaN      1                 NaN                 NaN
#
#       2018 PRICE VAR [%]  2019 PRICE VAR [%]
# PG                   NaN                 NaN
# VIPS                 NaN                 NaN
# KR                   NaN                 NaN
# RAD                  NaN                 NaN
# GIS                  NaN                 NaN
# ...                  ...                 ...
# YRIV                 NaN          -90.962099
# YTEN                 NaN          -77.922077
# ZKIN                 NaN          -17.834400
# ZOM                  NaN          -73.520000
# ZYME                 NaN          209.462222
#
# [22077 rows x 228 columns]

# %%
#creating train and test data in spirit of time series analysis

X_train=pd.concat([df14,df15,df16,df17])
X_test=df18

X_train.shape
# Out:
# (17685, 227)

# %%
# create variables for gdp and inflation per year
gdp14 = gdp.iloc[1][0] * 1000000000
gdp15 = gdp.iloc[2][0] * 1000000000
gdp16 = gdp.iloc[3][0] * 1000000000
gdp17 = gdp.iloc[4][0] * 1000000000
gdp18 = gdp.iloc[5][0] * 1000000000

infl14 = infl.iloc[0][0]
infl15 = infl.iloc[1][0]
infl16 = infl.iloc[2][0]
infl17 = infl.iloc[3][0]
infl18 = infl.iloc[4][0]

# %%
all_data=[df14,df15,df16,df17,df18]
all_gdp=[gdp14,gdp15,gdp16,gdp17,gdp18]
all_infl=[infl14,infl15,infl16,infl17,infl18]

for data, gdp in zip(all_data, all_gdp):
    data["GDP"] = gdp

for data, infl in zip(all_data, all_infl):
    data["Inflation"] = infl

# %%
#making one column with price var (neater if done here)
#no need for pipeline

df14.rename(columns={"2015 PRICE VAR [%]": "PRICE_VAR"},inplace=True)
df15.rename(columns={"2016 PRICE VAR [%]": "PRICE_VAR"},inplace=True)
df16.rename(columns={"2017 PRICE VAR [%]": "PRICE_VAR"},inplace=True)
df17.rename(columns={"2018 PRICE VAR [%]": "PRICE_VAR"},inplace=True)
df18.rename(columns={"2019 PRICE VAR [%]": "PRICE_VAR"},inplace=True)

# %%
#creating year variable

def year(data):
    all_data=[df14,df15,df16,df17,df18]
    count=0
    for data in all_data:
        data["year"]=2014+count
        count+=1
    
    #converting to cat. variable

    all_data=[df14,df15,df16,df17,df18]

    for data in all_data:
        data["year"]=data.year.astype("category")

#making a pipeline
add_year=Pipeline(steps=[("add_year",year(all_data))])

# %%
#creating the values with the perf. of the s&p to compare the companies to
sp14_performance=sp.loc["2014-12-31"].item()
sp15_performance=sp.loc["2015-12-31"].item()
sp16_performance=sp.loc["2016-12-30"].item()
sp17_performance=sp.loc["2017-12-29"].item()
sp18_performance=sp.loc["2018-12-31"].item()
#list with the performances
sp_performances=[sp14_performance,sp15_performance,sp16_performance,sp17_performance,sp18_performance]

# %%
#using encoder to make the categorical vars as that will still work when using the pipeline
from sklearn import preprocessing as pp
from sklearn.pipeline import Pipeline, FeatureUnion

all_data=[df14,df15,df16,df17,df18]

def categorize(data):

    le=pp.LabelEncoder()

    for data in all_data:
        data["Sector"]=le.fit_transform(data["Sector"])
        
#making a pipeline fot that stuff
sector_categorical=Pipeline(steps=[("sector_categorical",categorize(all_data))])

# %%
# Out:
#            Revenue  Revenue Growth  Cost of Revenue  Gross Profit  \
# PG    7.440100e+10         -0.0713     3.903000e+10  3.537100e+10
# VIPS  3.734148e+09          1.1737     2.805625e+09  9.285226e+08
# KR    9.837500e+10          0.0182     7.813800e+10  2.023700e+10
# RAD   2.552641e+10          0.0053     1.820268e+10  7.323734e+09
# GIS   1.790960e+10          0.0076     1.153980e+10  6.369800e+09
# ...            ...             ...              ...           ...
# YRIV  0.000000e+00          0.0000     0.000000e+00  0.000000e+00
# YTEN  5.560000e+05         -0.4110     0.000000e+00  5.560000e+05
# ZKIN  5.488438e+07          0.2210     3.659379e+07  1.829059e+07
# ZOM   0.000000e+00          0.0000     0.000000e+00  0.000000e+00
# ZYME  5.301900e+07          0.0243     0.000000e+00  5.301900e+07
#
#       R&D Expenses  SG&A Expense  Operating Expenses  Operating Income  \
# PG    0.000000e+00  2.146100e+10        2.146100e+10      1.391000e+10
# VIPS  1.083303e+08  3.441414e+08        7.939267e+08      1.345959e+08
# KR    0.000000e+00  1.519600e+10        1.751200e+10      2.725000e+09
# RAD   0.000000e+00  6.561162e+09        6.586482e+09      7.372520e+08
# GIS   0.000000e+00  3.474300e+09        3.412400e+09      2.957400e+09
# ...            ...           ...                 ...               ...
# YRIV  0.000000e+00  3.755251e+06        3.755251e+06     -3.755251e+06
# YTEN  4.759000e+06  5.071000e+06        9.830000e+06     -9.274000e+06
# ZKIN  1.652633e+06  7.020320e+06        8.672953e+06      9.617636e+06
# ZOM   1.031715e+07  4.521349e+06        1.664863e+07     -1.664863e+07
# ZYME  5.668400e+07  2.945700e+07        8.614600e+07     -3.312700e+07
#
#       Interest Expense  Earnings before Tax  ...  Book Value per Share Growth  \
# PG        7.090000e+08         1.449400e+10  ...                       0.0316
# VIPS      1.214869e+07         1.753823e+08  ...                          NaN
# KR        4.430000e+08         2.270000e+09  ...                       0.3268
# RAD       4.245910e+08         2.502180e+08  ...                       0.1963
# GIS       3.024000e+08         2.707700e+09  ...                       0.0274
# ...                ...                  ...  ...                          ...
# YRIV      1.105849e+07        -1.482451e+07  ...                      -0.1409
# YTEN      0.000000e+00        -9.170000e+06  ...                      -0.8602
# ZKIN      1.239170e+06         8.416324e+06  ...                       0.4074
# ZOM       0.000000e+00        -1.664769e+07  ...                      -0.2200
# ZYME      1.660000e+05        -3.438500e+07  ...                       0.1325
#
#       Debt Growth  R&D Expense Growth  SG&A Expenses Growth  Sector  \
# PG         0.1228              0.0000               -0.1746       3
# VIPS          NaN              1.6484                1.7313       3
# KR         0.2738              0.0000                0.0234       3
# RAD       -0.0458              0.0000               -0.0060       3
# GIS        0.1025              0.0000               -0.0220       3
# ...           ...                 ...                   ...     ...
# YRIV      -0.0152              0.0000               -0.2602       8
# YTEN       0.0000              0.0352               -0.0993       0
# ZKIN      -0.0968              0.2415                0.8987       0
# ZOM        0.0000              2.7499                0.1457       7
# ZYME       0.0000              0.3577                0.5880       6
#
#        PRICE_VAR  Class           GDP  Inflation  year
# PG     -9.323276      0  1.783845e+13     1.6222  2014
# VIPS  -25.512193      0  1.783845e+13     1.6222  2014
# KR     33.118297      1  1.783845e+13     1.6222  2014
# RAD     2.752291      1  1.783845e+13     1.6222  2014
# GIS    12.897715      1  1.783845e+13     1.6222  2014
# ...          ...    ...           ...        ...   ...
# YRIV  -90.962099      0  2.089137e+13     2.4426  2018
# YTEN  -77.922077      0  2.089137e+13     2.4426  2018
# ZKIN  -17.834400      0  2.089137e+13     2.4426  2018
# ZOM   -73.520000      0  2.089137e+13     2.4426  2018
# ZYME  209.462222      1  2.089137e+13     2.4426  2018
#
# [22077 rows x 227 columns]

# %%
#dropping unnecessary columns (e.g maybe class)
df=df.drop(columns=["Class"])

# %%
"""
#how many NAs are there and the percentage of missing values
df.isnull().sum().sort_values(ascending=False)/len(df)

def drop_na(data):
    #dropping the columns with more than one third of the cells missing
    df.dropna(axis="columns", thresh=(1/3)*len(df))

#pipeline
drop=Pipeline(steps=[("drop_na",drop_na(all_data))])
"""

# %%
len(df)
# Out:
# 22077

# %%
#outliers (saw that in the description)

# Get stocks that increased more than 200%
gain = 300
years_list = ["2015","2016","2017","2018"]
for i in years_list:
    top_gainers = df[df[i+" PRICE VAR [%]"] >= gain]
    top_gainers = top_gainers["2015 PRICE VAR [%]"].sort_values(ascending=False)
    print(f"{len(top_gainers)} STOCKS with more than {gain}% gain.")
    df = df.drop(top_gainers.index)
#we have 231 stocks with more than 200% gain

#we do not want these stocks as we think that they are "faked" (or typos etc.)
# Out:
# 25 STOCKS with more than 300% gain.
# 22 STOCKS with more than 300% gain.
# 37 STOCKS with more than 300% gain.
# 8 STOCKS with more than 300% gain.

# %%
# NANs
total_nans = df.isnull().sum().sort_values(ascending=False)
percent_nans = (df.isnull().sum()/df.isnull().count() * 100).sort_values(ascending=False)
# Zeros
total_zeros = df.isin([0]).sum().sort_values(ascending=False)
percent_zeros = (df.isin([0]).sum()/df.isin([0]).count() * 100).sort_values(ascending=False)

df_nans = pd.concat([total_nans, percent_nans], axis=1, keys=['Total NaN', 'Percent NaN'])
df_zeros = pd.concat([total_zeros, percent_zeros], axis=1, keys=['Total Zeros', 'Percent Zeros'])

# %%
# Find reasonable threshold for nan-values situation
test_nan_level = 0.7
print(df_nans.quantile(test_nan_level))
_, thresh_nan = df_nans.quantile(test_nan_level)

# Find reasonable threshold for zero-values situation
test_zeros_level = 0.8
print(df_zeros.quantile(test_zeros_level))
_, thresh_zeros = df_zeros.quantile(test_zeros_level)
# Out:
# Total NaN      3138.500000
# Percent NaN      14.495197
# Name: 0.7, dtype: float64
# Total Zeros      4985.000000
# Percent Zeros      23.023277
# Name: 0.8, dtype: float64

# %%
# Clean dataset applying thresholds for both zero values, nan-values
print(f'INITIAL NUMBER OF VARIABLES: {df.shape[1]}')
print()

df_test1 = df.drop((df_nans[df_nans['Percent NaN'] > thresh_nan]).index, 1)
print(f'NUMBER OF VARIABLES AFTER NaN THRESHOLD {thresh_nan:.2f}%: {df_test1.shape[1]}')
print()

df_zeros_postnan = df_zeros.drop((df_nans[df_nans['Percent NaN'] > thresh_nan]).index, axis=0)
df = df_test1.drop((df_zeros_postnan[df_zeros_postnan['Percent Zeros'] > thresh_zeros]).index, 1)
print(f'NUMBER OF VARIABLES AFTER Zeros THRESHOLD {thresh_zeros:.2f}%: {df_test2.shape[1]}')
# Out:
# INITIAL NUMBER OF VARIABLES: 226
#
# NUMBER OF VARIABLES AFTER NaN THRESHOLD 14.50%: 158
#
# NUMBER OF VARIABLES AFTER Zeros THRESHOLD 23.02%: 120

# %%
df.dtypes
df.select_dtypes(include="float64")
# Out:
#            Revenue  Revenue Growth  Gross Profit  SG&A Expense  \
# PG    7.440100e+10         -0.0713  3.537100e+10  2.146100e+10
# VIPS  3.734148e+09          1.1737  9.285226e+08  3.441414e+08
# KR    9.837500e+10          0.0182  2.023700e+10  1.519600e+10
# RAD   2.552641e+10          0.0053  7.323734e+09  6.561162e+09
# GIS   1.790960e+10          0.0076  6.369800e+09  3.474300e+09
# ...            ...             ...           ...           ...
# XTLB  0.000000e+00          0.0000  0.000000e+00  7.550000e+05
# YTEN  5.560000e+05         -0.4110  5.560000e+05  5.071000e+06
# ZKIN  5.488438e+07          0.2210  1.829059e+07  7.020320e+06
# ZOM   0.000000e+00          0.0000  0.000000e+00  4.521349e+06
# ZYME  5.301900e+07          0.0243  5.301900e+07  2.945700e+07
#
#       Operating Expenses  Operating Income  Earnings before Tax    Net Income  \
# PG          2.146100e+10      1.391000e+10         1.449400e+10  1.164300e+10
# VIPS        7.939267e+08      1.345959e+08         1.753823e+08  1.358227e+08
# KR          1.751200e+10      2.725000e+09         2.270000e+09  1.519000e+09
# RAD         6.586482e+09      7.372520e+08         2.502180e+08  2.494140e+08
# GIS         3.412400e+09      2.957400e+09         2.707700e+09  1.824400e+09
# ...                  ...               ...                  ...           ...
# XTLB        7.930000e+05     -7.930000e+05         2.986000e+06  2.986000e+06
# YTEN        9.830000e+06     -9.274000e+06        -9.170000e+06 -9.170000e+06
# ZKIN        8.672953e+06      9.617636e+06         8.416324e+06  7.018114e+06
# ZOM         1.664863e+07     -1.664863e+07        -1.664769e+07 -1.664769e+07
# ZYME        8.614600e+07     -3.312700e+07        -3.438500e+07 -3.655600e+07
#
#       Net Income Com     EPS  ...     ROE  Capex per Share  \
# PG      1.164300e+10  4.1900  ...  0.1664          -1.4220
# VIPS    1.358227e+08  0.2396  ...  0.3294         -17.8582
# KR      1.519000e+09  1.4700  ...  0.2821          -2.2665
# RAD     2.154160e+08  4.6000  ... -0.1180          -6.9087
# GIS     1.824400e+09  2.9000  ...  0.2792          -1.0690
# ...              ...     ...  ...     ...              ...
# XTLB    2.986000e+06  0.6000  ...  0.3588           0.0000
# YTEN   -9.170000e+06 -0.9200  ... -1.6093          -0.0042
# ZKIN    7.018114e+06  0.5200  ...  0.1895          -0.0343
# ZOM    -1.664769e+07 -0.1800  ... -4.5523          -0.0066
# ZYME   -3.655600e+07 -1.2600  ... -0.2025          -0.0276
#
#       Gross Profit Growth  EBIT Growth  Operating Income Growth  \
# PG                -0.1185      -0.0001                   0.0067
# VIPS               1.2489       1.6142                   1.9463
# KR                 0.0173      -0.0145                  -0.0141
# RAD                0.0007       0.2904                   0.1113
# GIS               -0.0084       0.0332                   0.0370
# ...                   ...          ...                      ...
# XTLB               0.0000       4.8233                   0.3636
# YTEN              -0.4110       0.0241                   0.0010
# ZKIN               0.3953       0.1899                   0.1903
# ZOM                0.0000      -1.0642                  -1.0594
# ZYME               0.0243      -2.5869                  -2.6816
#
#       Net Income Growth  EPS Growth  EPS Diluted Growth  \
# PG               0.0293      0.0371              0.0389
# VIPS             1.5649      1.4625              1.4646
# KR               0.0147      0.0576              0.0469
# RAD              1.0043      0.9167              0.9167
# GIS             -0.0166      0.0140              0.0143
# ...                 ...         ...                 ...
# XTLB             4.8233      4.0000              4.0000
# YTEN             0.1527      0.7204              0.7204
# ZKIN             0.1947     -0.0714             -0.0714
# ZOM             -1.0642     -1.0000             -1.0000
# ZYME            -2.5130     -1.4706             -0.9688
#
#       Operating Cash Flow growth  Asset Growth
# PG                       -0.0615        0.0359
# VIPS                      0.2134           NaN
# KR                        0.2095        0.1886
# RAD                      -0.1434       -0.0189
# GIS                      -0.1316        0.0215
# ...                          ...           ...
# XTLB                      0.2747        0.3020
# YTEN                     -0.0673       -0.2323
# ZKIN                     -2.9498        0.2489
# ZOM                      -0.5716        0.1568
# ZYME                    109.3973        0.8519
#
# [21597 rows x 57 columns]

# %%
#visualization
#outliers (saw that in the description)

#df14_outliers=df14.loc[:,["Sector", "2015 PRICE VAR [%]"]]

#sector_list=df14_outliers["Sector"].unique()

#plot the price variations per sector
#for sector in sector_list:
    
    #temp=df14_outliers[df14_outliers["Sector"] == sector]
    
    #plt.figure(figsize=(30,5))
    #plt.plot(temp["2015 PRICE VAR [%]"])
    #plt.title(sector.upper(),fontsize=20)
    #plt.show()

#price_growth=500
#gains=df14_outliers[df14_outliers["2015 PRICE VAR [%]"]>=price_growth]
#print(gains)

# %%
#for just one column (problem with length)

all_data = [df14, df15, df16, df17, df18]
sp_performances

for data, value in zip(all_data,sp_performances):
        data["strategy"] = np.where((data["PRICE_VAR"].subtract(value)) >= 2.5, ["buy"], data["strategy"])
        data["strategy"] = np.where((data["PRICE_VAR"].subtract(value) < 2.5) &
                            (data["PRICE_VAR"].subtract(value) > -2.5), ["hold"], data["strategy"])
        data["strategy"] = np.where((data["PRICE_VAR"].subtract(value)) <= -2.5, ["sell"], data["strategy"])

#making it a categorical variable where 2 is sell, 1 is hold and 0 is buy

le=pp.LabelEncoder()

for data in all_data:
        data["strategy"]=le.fit_transform(data["strategy"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'strategy'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-2c6fcaee3b4c> in <module>
#       5
#       6 for data, value in zip(all_data,sp_performances):
# ----> 7         data["strategy"] = np.where((data["PRICE_VAR"].subtract(value)) >= 2.5, ["buy"], data["strategy"])
#       8         data["strategy"] = np.where((data["PRICE_VAR"].subtract(value) < 2.5) &
#       9                             (data["PRICE_VAR"].subtract(value) > -2.5), ["hold"], data["strategy"])
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'strategy'

# %%
df.drop(['Sector'], axis=1, inplace=True)

# %%
#imputer stuff --> important that we finish that
def imputer(data):
    
    imputer=IterativeImputer(max_iter=10,random_state=0)
    imputer.fit(data)
    df_filled=imputer.transform(data)

    return df_filled

z = imputer(df)


#impute=Pipeline(steps=[("imputer",imputer(all_data))])
# Out:
# C:\Users\frede\anaconda3\lib\site-packages\sklearn\impute\_iterative.py:669: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn("[IterativeImputer] Early stopping criterion not"

# %%
z = pd.DataFrame(z)
z.columns = list(df)
z.describe
# Out:
# <bound method NDFrame.describe of             Revenue  Revenue Growth  Cost of Revenue  Gross Profit  \
# 0      7.440100e+10         -0.0713     3.903000e+10  3.537100e+10
# 1      3.734148e+09          1.1737     2.805625e+09  9.285226e+08
# 2      9.837500e+10          0.0182     7.813800e+10  2.023700e+10
# 3      2.552641e+10          0.0053     1.820268e+10  7.323734e+09
# 4      1.790960e+10          0.0076     1.153980e+10  6.369800e+09
# ...             ...             ...              ...           ...
# 21647  0.000000e+00          0.0000     0.000000e+00  0.000000e+00
# 21648  5.560000e+05         -0.4110     0.000000e+00  5.560000e+05
# 21649  5.488438e+07          0.2210     3.659379e+07  1.829059e+07
# 21650  0.000000e+00          0.0000     0.000000e+00  0.000000e+00
# 21651  5.301900e+07          0.0243     0.000000e+00  5.301900e+07
#
#        SG&A Expense  Operating Expenses  Operating Income  \
# 0      2.146100e+10        2.146100e+10      1.391000e+10
# 1      3.441414e+08        7.939267e+08      1.345959e+08
# 2      1.519600e+10        1.751200e+10      2.725000e+09
# 3      6.561162e+09        6.586482e+09      7.372520e+08
# 4      3.474300e+09        3.412400e+09      2.957400e+09
# ...             ...                 ...               ...
# 21647  7.550000e+05        7.930000e+05     -7.930000e+05
# 21648  5.071000e+06        9.830000e+06     -9.274000e+06
# 21649  7.020320e+06        8.672953e+06      9.617636e+06
# 21650  4.521349e+06        1.664863e+07     -1.664863e+07
# 21651  2.945700e+07        8.614600e+07     -3.312700e+07
#
#        Earnings before Tax  Income Tax Expense    Net Income  ...  EPS Growth  \
# 0             1.449400e+10        2.851000e+09  1.164300e+10  ...      0.0371
# 1             1.753823e+08        3.955957e+07  1.358227e+08  ...      1.4625
# 2             2.270000e+09        7.510000e+08  1.519000e+09  ...      0.0576
# 3             2.502180e+08        8.040000e+05  2.494140e+08  ...      0.9167
# 4             2.707700e+09        8.833000e+08  1.824400e+09  ...      0.0140
# ...                    ...                 ...           ...  ...         ...
# 21647         2.986000e+06        0.000000e+00  2.986000e+06  ...      4.0000
# 21648        -9.170000e+06        0.000000e+00 -9.170000e+06  ...      0.7204
# 21649         8.416324e+06        1.398210e+06  7.018114e+06  ...     -0.0714
# 21650        -1.664769e+07        0.000000e+00 -1.664769e+07  ...     -1.0000
# 21651        -3.438500e+07        2.171000e+06 -3.655600e+07  ...     -1.4706
#
#        EPS Diluted Growth  Weighted Average Shares Growth  \
# 0                  0.0389                         -0.0127
# 1                  1.4646                          0.0184
# 2                  0.0469                         -0.0356
# 3                  0.9167                          0.0694
# 4                  0.0143                         -0.0468
# ...                   ...                             ...
# 21647              4.0000                          0.0936
# 21648              0.7204                          2.0203
# 21649             -0.0714                          0.2407
# 21650             -1.0000                          0.0691
# 21651             -0.9688                          0.3690
#
#        Operating Cash Flow growth  Free Cash Flow growth  Receivables growth  \
# 0                         -0.0615                -0.0695           -0.018700
# 1                          0.2134                -0.3626          140.658479
# 2                          0.2095                 0.3935            0.061800
# 3                         -0.1434                -0.2691            0.021100
# 4                         -0.1316                -0.1936            0.025700
# ...                           ...                    ...                 ...
# 21647                      0.2747                 0.2740            0.000000
# 21648                     -0.0673                -0.0716            0.344500
# 21649                     -2.9498                -3.7263            0.160500
# 21650                     -0.5716                -0.6197            0.898000
# 21651                    109.3973                14.0145           -0.418500
#
#        Asset Growth  Book Value per Share Growth  Debt Growth  \
# 0          0.035900                     0.031600     0.122800
# 1        -15.470455                   -10.595479     3.625777
# 2          0.188600                     0.326800     0.273800
# 3         -0.018900                     0.196300    -0.045800
# 4          0.021500                     0.027400     0.102500
# ...             ...                          ...          ...
# 21647      0.302000                     1.101300     0.000000
# 21648     -0.232300                    -0.860200     0.000000
# 21649      0.248900                     0.407400    -0.096800
# 21650      0.156800                    -0.220000     0.000000
# 21651      0.851900                     0.132500     0.000000
#
#        SG&A Expenses Growth
# 0                   -0.1746
# 1                    1.7313
# 2                    0.0234
# 3                   -0.0060
# 4                   -0.0220
# ...                     ...
# 21647               -0.3724
# 21648               -0.0993
# 21649                0.8987
# 21650                0.1457
# 21651                0.5880
#
# [21652 rows x 120 columns]>

# %%
z.isnull().sum()
# Out:
# Revenue                        0
# Revenue Growth                 0
# Cost of Revenue                0
# Gross Profit                   0
# SG&A Expense                   0
#                               ..
# Receivables growth             0
# Asset Growth                   0
# Book Value per Share Growth    0
# Debt Growth                    0
# SG&A Expenses Growth           0
# Length: 120, dtype: int64

# %%
z.isin([0]).sum()
# Out:
# Revenue                         879
# Revenue Growth                  928
# Cost of Revenue                4201
# Gross Profit                    875
# SG&A Expense                    492
#                                ...
# Receivables growth             3202
# Asset Growth                     35
# Book Value per Share Growth      28
# Debt Growth                    3594
# SG&A Expenses Growth            491
# Length: 120, dtype: int64

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-5871c10638cb> in <module>
#       2
#       3 # Drop Nan row
# ----> 4 df = df.dropna(how='all', inplace=True)
#       5 df = df.drop(['Sector'], axis=1, inplace=True)
#       6 df2 = df.drop(df2.columns[0], axis = 1)
#
# AttributeError: 'NoneType' object has no attribute 'dropna'

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-658701e0b980> in <module>
#       4
#       5 # Impute using fit_tranform on training set
# ----> 6 df_imputed = imputer.fit_transform(df)
#
# ~\anaconda3\lib\site-packages\sklearn\impute\_iterative.py in fit_transform(self, X, y)
#     593         super()._fit_indicator(X)
#     594         X_indicator = super()._transform_indicator(X)
# --> 595         X, Xt, mask_missing_values = self._initial_imputation(X)
#     596         if self.max_iter == 0 or np.all(mask_missing_values):
#     597             self.n_iter_ = 0
#
# ~\anaconda3\lib\site-packages\sklearn\impute\_iterative.py in _initial_imputation(self, X)
#     496             force_all_finite = True
#     497
# --> 498         X = self._validate_data(X, dtype=FLOAT_DTYPES, order="F",
#     499                                 force_all_finite=force_all_finite)
#     500         _check_inputs_dtype(X, self.missing_values)
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     418                     f"requires y to be passed, but the target y is None."
#     419                 )
# --> 420             X = check_array(X, **check_params)
#     421             out = X
#     422         else:
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     596                     array = array.astype(dtype, casting="unsafe", copy=False)
#     597                 else:
# --> 598                     array = np.asarray(array, order=order, dtype=dtype)
#     599             except ComplexWarning:
#     600                 raise ValueError("Complex data not supported\n"
#
# ~\anaconda3\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order)
#      81
#      82     """
# ---> 83     return array(a, dtype, copy=False, order=order)
#      84
#      85
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __array__(self, dtype)
#    1779
#    1780     def __array__(self, dtype=None) -> np.ndarray:
# -> 1781         return np.asarray(self._values, dtype=dtype)
#    1782
#    1783     def __array_wrap__(self, result, context=None):
#
# ~\anaconda3\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order)
#      81
#      82     """
# ---> 83     return array(a, dtype, copy=False, order=order)
#      84
#      85
#
# ValueError: could not convert string to float: 'Consumer Defensive'

# %%
# Out:
# <bound method NDFrame.describe of            Revenue  Revenue Growth  Cost of Revenue  Gross Profit  \
# PG    7.440100e+10         -0.0713     3.903000e+10  3.537100e+10
# VIPS  3.734148e+09          1.1737     2.805625e+09  9.285226e+08
# KR    9.837500e+10          0.0182     7.813800e+10  2.023700e+10
# RAD   2.552641e+10          0.0053     1.820268e+10  7.323734e+09
# GIS   1.790960e+10          0.0076     1.153980e+10  6.369800e+09
# ...            ...             ...              ...           ...
# YRIV  0.000000e+00          0.0000     0.000000e+00  0.000000e+00
# YTEN  5.560000e+05         -0.4110     0.000000e+00  5.560000e+05
# ZKIN  5.488438e+07          0.2210     3.659379e+07  1.829059e+07
# ZOM   0.000000e+00          0.0000     0.000000e+00  0.000000e+00
# ZYME  5.301900e+07          0.0243     0.000000e+00  5.301900e+07
#
#       R&D Expenses  SG&A Expense  Operating Expenses  Operating Income  \
# PG    0.000000e+00  2.146100e+10        2.146100e+10      1.391000e+10
# VIPS  1.083303e+08  3.441414e+08        7.939267e+08      1.345959e+08
# KR    0.000000e+00  1.519600e+10        1.751200e+10      2.725000e+09
# RAD   0.000000e+00  6.561162e+09        6.586482e+09      7.372520e+08
# GIS   0.000000e+00  3.474300e+09        3.412400e+09      2.957400e+09
# ...            ...           ...                 ...               ...
# YRIV  0.000000e+00  3.755251e+06        3.755251e+06     -3.755251e+06
# YTEN  4.759000e+06  5.071000e+06        9.830000e+06     -9.274000e+06
# ZKIN  1.652633e+06  7.020320e+06        8.672953e+06      9.617636e+06
# ZOM   1.031715e+07  4.521349e+06        1.664863e+07     -1.664863e+07
# ZYME  5.668400e+07  2.945700e+07        8.614600e+07     -3.312700e+07
#
#       Interest Expense  Earnings before Tax  ...  Book Value per Share Growth  \
# PG        7.090000e+08         1.449400e+10  ...                       0.0316
# VIPS      1.214869e+07         1.753823e+08  ...                          NaN
# KR        4.430000e+08         2.270000e+09  ...                       0.3268
# RAD       4.245910e+08         2.502180e+08  ...                       0.1963
# GIS       3.024000e+08         2.707700e+09  ...                       0.0274
# ...                ...                  ...  ...                          ...
# YRIV      1.105849e+07        -1.482451e+07  ...                      -0.1409
# YTEN      0.000000e+00        -9.170000e+06  ...                      -0.8602
# ZKIN      1.239170e+06         8.416324e+06  ...                       0.4074
# ZOM       0.000000e+00        -1.664769e+07  ...                      -0.2200
# ZYME      1.660000e+05        -3.438500e+07  ...                       0.1325
#
#       Debt Growth  R&D Expense Growth  SG&A Expenses Growth  \
# PG         0.1228              0.0000               -0.1746
# VIPS          NaN              1.6484                1.7313
# KR         0.2738              0.0000                0.0234
# RAD       -0.0458              0.0000               -0.0060
# GIS        0.1025              0.0000               -0.0220
# ...           ...                 ...                   ...
# YRIV      -0.0152              0.0000               -0.2602
# YTEN       0.0000              0.0352               -0.0993
# ZKIN      -0.0968              0.2415                0.8987
# ZOM        0.0000              2.7499                0.1457
# ZYME       0.0000              0.3577                0.5880
#
#                   Sector  2015 PRICE VAR [%]  2016 PRICE VAR [%]  \
# PG    Consumer Defensive           -9.323276                 NaN
# VIPS  Consumer Defensive          -25.512193                 NaN
# KR    Consumer Defensive           33.118297                 NaN
# RAD   Consumer Defensive            2.752291                 NaN
# GIS   Consumer Defensive           12.897715                 NaN
# ...                  ...                 ...                 ...
# YRIV         Real Estate                 NaN                 NaN
# YTEN     Basic Materials                 NaN                 NaN
# ZKIN     Basic Materials                 NaN                 NaN
# ZOM          Industrials                 NaN                 NaN
# ZYME          Healthcare                 NaN                 NaN
#
#       2017 PRICE VAR [%]  2018 PRICE VAR [%]  2019 PRICE VAR [%]
# PG                   NaN                 NaN                 NaN
# VIPS                 NaN                 NaN                 NaN
# KR                   NaN                 NaN                 NaN
# RAD                  NaN                 NaN                 NaN
# GIS                  NaN                 NaN                 NaN
# ...                  ...                 ...                 ...
# YRIV                 NaN                 NaN          -90.962099
# YTEN                 NaN                 NaN          -77.922077
# ZKIN                 NaN                 NaN          -17.834400
# ZOM                  NaN                 NaN          -73.520000
# ZYME                 NaN                 NaN          209.462222
#
# [22077 rows x 227 columns]>

# %%
#evaluation function for the algos (from towards data science; might be useful later)

def evaluation(y, y_hat, title = 'Confusion Matrix'):
    cm = confusion_matrix(y, y_hat)
    precision = precision_score(y, y_hat)
    recall = recall_score(y, y_hat)
    accuracy = accuracy_score(y,y_hat)
    f1 = f1_score(y,y_hat)
    print('Recall: ', recall)
    print('Accuracy: ', accuracy)
    print('Precision: ', precision)
    print('F1: ', f1)
    sns.heatmap(cm,  cmap= 'PuBu', annot=True, fmt='g', annot_kws=    {'size':20})
    plt.xlabel('predicted', fontsize=18)
    plt.ylabel('actual', fontsize=18)
    plt.title(title, fontsize=18)
    
    plt.show();

# %%
#pipelining all of the above to prevent leakage from test data into training data which might be useful later (from tds)
def cross_validate(classifier, cv):
    pipeline = Pipeline(steps=[
        ('preprocess', preprocess),
        ('classifier', classifier)
    ])
    train_acc = []
    test_acc = []
    for train_ind, val_ind in cv.split(X_train, y_train):
        X_t, y_t = X_train.iloc[train_ind], y_train[train_ind]
        pipeline.fit(X_t, y_t)
        y_hat_t = pipeline.predict(X_t)
        train_acc.append(accuracy_score(y_t, y_hat_t))
        X_val, y_val = X_train.iloc[val_ind], y_train[val_ind]
        y_hat_val = pipeline.predict(X_val)
        test_acc.append(accuracy_score(y_val, y_hat_val))
    print(evaluation(y_val, y_hat_val))
    print('Training Accuracy: {}'.format(np.mean(train_acc)))
    print('\n')
    print('Validation Accuracy: {}'.format(np.mean(test_acc)))
    print('\n')

# %% [markdown]
# main determinants of stock prices
# (i) perceived risk --> risk measure
# (ii) price forecast --> maybe a time series forecast
# (iii) underlying variables (our dataset) --> we have got plenty of that
# (iv) inflation --> we have got that

# %%
#feature selection
#does not work yet as we have NA values --> important that we finish the imputer stuff

def select_features(X,Y,threshold):
    
    #X are the features with whom we want to classify Y [Strategy] and threshold being a threshold [percentages]
    
    features=X.columns[:]
    
    forest=RandomForestClassifier(random_state=1,class_weight="balanced")
    forest.fit(X,Y)
    importances=forest.feature_importances_
    
    #Define n as number of importances over the value thres
    n = sum(importances > threshold)
    
    # Get cumsum of the n most important features
    feat_imp = np.sort(importances)[::-1]
    sum_feat_imp = np.cumsum(feat_imp)[:n]
    
    # Sort output (by relative importance) and 
    # print top n features
    indices = np.argsort(importances)[::-1]
    for i in range(n):
        print('{0:2d}) {1:7s} {2:6.4f}'.format(i + 1, 
                                           features[indices[i]],
                                           importances[indices[i]]))
        
    
    # Plot Feature Importance (both cumul., individual)
    plt.figure(figsize=(12, 8))
    plt.bar(range(n), importances[indices[:n]], align='center')
    plt.xticks(range(n), features[indices[:n]], rotation=90)
    plt.xlim([-1, n])
    plt.xlabel('Feature')
    plt.ylabel('Rel. Feature Importance')
    plt.step(range(n), sum_feat_imp, where='mid', 
         label='Cumulative importance')
    plt.tight_layout();
    
    
    # Create a list with the important features for ML algorhithms
    feature_list = [None] * n
    for i in range(n):
        feature_list[i] = features[indices[i]]
    
    # return the list of important features
    return feature_list

X=df.drop(columns=["strategy"])
select_features(X,df["strategy"],20)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-150-f18240df515e> in <module>
#      48
#      49 X=df.drop(columns=["strategy"])
# ---> 50 select_features(X,df["strategy"],20)
#
# <ipython-input-150-f18240df515e> in select_features(X, Y, threshold)
#       8
#       9     forest=RandomForestClassifier(random_state=1,class_weight="balanced")
# ---> 10     forest.fit(X,Y)
#      11     importances=forest.feature_importances_
#      12
#
# ~\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in fit(self, X, y, sample_weight)
#     301                 "sparse multilabel-indicator for y is not supported."
#     302             )
# --> 303         X, y = self._validate_data(X, y, multi_output=True,
#     304                                    accept_sparse="csc", dtype=DTYPE)
#     305         if sample_weight is not None:
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     430                 y = check_array(y, **check_y_params)
#     431             else:
# --> 432                 X, y = check_X_y(X, y, **check_params)
#     433             out = X, y
#     434
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     793         raise ValueError("y cannot be None")
#     794
# --> 795     X = check_array(X, accept_sparse=accept_sparse,
#     796                     accept_large_sparse=accept_large_sparse,
#     797                     dtype=dtype, order=order, copy=copy,
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     642
#     643         if force_all_finite:
# --> 644             _assert_all_finite(array,
#     645                                allow_nan=force_all_finite == 'allow-nan')
#     646
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#      94                 not allow_nan and not np.isfinite(X).all()):
#      95             type_err = 'infinity' if allow_nan else 'NaN, infinity'
# ---> 96             raise ValueError(
#      97                     msg_err.format
#      98                     (type_err,
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').

# %%
#creating a risk meaure for each stock
indizes=df.index.values.tolist()

for index in indizes:
    stock(index)=df.groupby(df.index).get_group(index)
    
#gets vars later
# Out:
#   File "<ipython-input-199-6415792f1720>", line 7
#     stock(index)=df.groupby(df.index).get_group(index)
#     ^
# SyntaxError: cannot assign to function call

# %%
indizes
# Out:
# ['PG',
#  'VIPS',
#  'KR',
#  'RAD',
#  'GIS',
#  'PM',
#  'KO',
#  'WMT',
#  'MDLZ',
#  'MO',
#  'ABEV',
#  'TAL',
#  'BRFS',
#  'KHC',
#  'NWL',
#  'KMB',
#  'CPB',
#  'TGT',
#  'HRL',
#  'CAG',
#  'PEP',
#  'COST',
#  'COTY',
#  'MNST',
#  'SJM',
#  'CL',
#  'ADM',
#  'DG',
#  'TAP',
#  'SYY',
#  'CHD',
#  'BG',
#  'PBH',
#  'BIG',
#  'STZ',
#  'SFM',
#  'AVP',
#  'HMHC',
#  'POST',
#  'EL',
#  'PPC',
#  'DLTR',
#  'GNC',
#  'DF',
#  'HLF',
#  'TWNK',
#  'BUD',
#  'CHGG',
#  'AGRO',
#  'CASY',
#  'MGPI',
#  'EDU',
#  'TSN',
#  'MKC',
#  'HAIN',
#  'HSY',
#  'PFGC',
#  'UN',
#  'CHEF',
#  'PRMW',
#  'FRPT',
#  'FMX',
#  'CLX',
#  'VGR',
#  'SPB',
#  'PETS',
#  'THS',
#  'OLLI',
#  'BURL',
#  'IPAR',
#  'INGR',
#  'SAFM',
#  'DEO',
#  'UNFI',
#  'UL',
#  'LOPE',
#  'EPC',
#  'CCU',
#  'CALM',
#  'CORE',
#  'CRESY',
#  'FIZZ',
#  'UVV',
#  'FDP',
#  'NUS',
#  'PSMT',
#  'CENTA',
#  'LBY',
#  'HELE',
#  'CVGW',
#  'TUES',
#  'TEDU',
#  'ATGE',
#  'UTI',
#  'CENT',
#  'LANC',
#  'SAM',
#  'WMK',
#  'STRA',
#  'GPX',
#  'APEI',
#  'KOF',
#  'NBEV',
#  'NAUH',
#  'IMKTA',
#  'CECO',
#  'TR',
#  'ANDE',
#  'VLGEA',
#  'REV',
#  'JBSS',
#  'LRN',
#  'HLG',
#  'JJSF',
#  'RIBT',
#  'FC',
#  'LNDC',
#  'LMNR',
#  'CELH',
#  'FARM',
#  'BREW',
#  'SEED',
#  'COKE',
#  'ANFI',
#  'DL',
#  'COE',
#  'LBCC',
#  'SENEA',
#  'CHSCM',
#  'CHSCN',
#  'BRID',
#  'CHSCL',
#  'LFVN',
#  'NAII',
#  'SANW',
#  'YGYI',
#  'UG',
#  'LWAY',
#  'ACU',
#  'ALCO',
#  'ASPU',
#  'CHSCO',
#  'CHSCP',
#  'CJJD',
#  'CYAN',
#  'DIT',
#  'DTEA',
#  'FTFT',
#  'IBA',
#  'JVA',
#  'LINC',
#  'LND',
#  'MTEX',
#  'NATR',
#  'NGVC',
#  'NHTC',
#  'OBCI',
#  'PME',
#  'REED',
#  'RELV',
#  'RMCF',
#  'SENEB',
#  'THST',
#  'WILC',
#  'WVVI',
#  'CX',
#  'VALE',
#  'AKS',
#  'GSM',
#  'FCX',
#  'NUE',
#  'X',
#  'AUY',
#  'CLF',
#  'GFI',
#  'KGC',
#  'HMY',
#  'NGD',
#  'GGB',
#  'TS',
#  'AA',
#  'EGO',
#  'OLN',
#  'JCI',
#  'AU',
#  'CMC',
#  'MAS',
#  'TECK',
#  'TRQ',
#  'WPM',
#  'BTG',
#  'CENX',
#  'HL',
#  'STLD',
#  'AWI',
#  'CDE',
#  'CE',
#  'HUN',
#  'CSTM',
#  'IAG',
#  'WY',
#  'SID',
#  'SLCA',
#  'CF',
#  'LYB',
#  'VMC',
#  'CC',
#  'LPX',
#  'NEM',
#  'MEOH',
#  'RIO',
#  'EMN',
#  'MLM',
#  'FOE',
#  'MOS',
#  'MT',
#  'CCJ',
#  'AXTA',
#  'AEM',
#  'PVG',
#  'ASH',
#  'ARLP',
#  'BHP',
#  'AGI',
#  'CBT',
#  'AG',
#  'KS',
#  'NG',
#  'HCLP',
#  'BCC',
#  'UEC',
#  'SQM',
#  'SXT',
#  'FMC',
#  'SCCO',
#  'BMCH',
#  'GRA',
#  'SUM',
#  'MUX',
#  'TROX',
#  'OEC',
#  'SBGL',
#  'ALB',
#  'OC',
#  'EXP',
#  'MDU',
#  'SAND',
#  'ECL',
#  'RYN',
#  'PPG',
#  'TMST',
#  'FNV',
#  'FUL',
#  'BVN',
#  'EXK',
#  'BBL',
#  'UNVR',
#  'FSM',
#  'PAAS',
#  'UUUU',
#  'SHW',
#  'SSRM',
#  'UFS',
#  'HBM',
#  'VEDL',
#  'MAG',
#  'CRH',
#  'IPI',
#  'BLDR',
#  'GPRE',
#  'RPM',
#  'CMP',
#  'IFF',
#  'AVD',
#  'SMG',
#  'HSC',
#  'WLK',
#  'USCR',
#  'WLKP',
#  'APD',
#  'SXC',
#  'ROCK',
#  'GOLD',
#  'OR',
#  'OMN',
#  'KRA',
#  'URG',
#  'LXU',
#  'AMWD',
#  'BXC',
#  'RFP',
#  'CSTE',
#  'IIIN',
#  'BLD',
#  'UAN',
#  'SWM',
#  'GLT',
#  'MERC',
#  'AGFS',
#  'RYAM',
#  'PKX',
#  'AXE',
#  'TX',
#  'GSS',
#  'DOOR',
#  'SA',
#  'MTRN',
#  'ALO',
#  'VGZ',
#  'NAK',
#  'THM',
#  'UFPI',
#  'GSV',
#  'POL',
#  'KALU',
#  'KRO',
#  'RGLD',
#  'EVA',
#  'MTX',
#  'TREX',
#  'GPL',
#  'IBP',
#  'AMRS',
#  'KOP',
#  'APOG',
#  'AAON',
#  'AKG',
#  'REX',
#  'CBPX',
#  'IPHS',
#  'KMG',
#  'NX',
#  'GORO',
#  'AMTX',
#  'ICL',
#  'NEU',
#  'BCPC',
#  'TREC',
#  'WWR',
#  'RKDA',
#  'LODE',
#  'TANH',
#  'VHI',
#  'CLW',
#  'HWKN',
#  'GFF',
#  'XPL',
#  'MTL',
#  'NRP',
#  'TGB',
#  'APT',
#  'NWPX',
#  'SCL',
#  'WDFC',
#  'NP',
#  'TGLS',
#  'ACH',
#  'DNN',
#  'IOSP',
#  'PLM',
#  'FF',
#  'KWR',
#  'AUMN',
#  'CMCL',
#  'NTIC',
#  'MBII',
#  'TGEN',
#  'ASPN',
#  'CPAC',
#  'GURE',
#  'OSN',
#  'USAU',
#  'PZG',
#  'AAU',
#  'ASM',
#  'CCCL',
#  'CCR',
#  'CGA',
#  'CHNR',
#  'CINR',
#  'CTHR',
#  'DRD',
#  'EMX',
#  'FRD',
#  'FSI',
#  'GEVO',
#  'GMO',
#  'HNRG',
#  'IGC',
#  'IKNX',
#  'JCTCF',
#  'JHX',
#  'KGJI',
#  'MPVD',
#  'ODC',
#  'PLG',
#  'POPE',
#  'SES',
#  'SIM',
#  'SPPP',
#  'TMQ',
#  'TRX',
#  'UAMY',
#  'USAP',
#  'USLM',
#  'WRN',
#  'YTEN',
#  'PFE',
#  'BMY',
#  'GERN',
#  'GILD',
#  'ABBV',
#  'MRK',
#  'JNJ',
#  'BSX',
#  'ABT',
#  'WBA',
#  'CDNA',
#  'MDT',
#  'CVS',
#  'UNH',
#  'CNC',
#  'CI',
#  'SYNH',
#  'CELG',
#  'BIIB',
#  'GSK',
#  'TEVA',
#  'MYL',
#  'XRAY',
#  'PGNX',
#  'IMGN',
#  'GKOS',
#  'ALXN',
#  'IDRA',
#  'RIGL',
#  'ENDP',
#  'OMER',
#  'AMGN',
#  'TLGT',
#  'PDCO',
#  'BKD',
#  'BDX',
#  'HOLX',
#  'ANTM',
#  'ZBH',
#  'NVAX',
#  'TNDM',
#  'DXCM',
#  'LLY',
#  'HSIC',
#  'CYH',
#  'THC',
#  'SRNE',
#  'OPK',
#  'BAX',
#  'AGN',
#  'HCA',
#  'VRTX',
#  'NKTR',
#  'A',
#  'MNK',
#  'AZN',
#  'DHR',
#  'IMMU',
#  'FOLD',
#  'PDLI',
#  'DVAX',
#  'PKI',
#  'UHS',
#  'ACHC',
#  'NVS',
#  'TTPH',
#  'VRAY',
#  'ALNY',
#  'BMRN',
#  'HRTX',
#  'TXMD',
#  'INSM',
#  'EXEL',
#  'HZNP',
#  'AKBA',
#  'TMO',
#  'ACAD',
#  'ARNA',
#  'QGEN',
#  'CLVS',
#  'ARQL',
#  'LIVN',
#  'AMAG',
#  'DGX',
#  'HALO',
#  'SGMO',
#  'MCK',
#  'ABC',
#  'NVO',
#  'VNDA',
#  'EW',
#  'AMRN',
#  'IONS',
#  'NEOS',
#  'ZTS',
#  'BDSI',
#  'AKRX',
#  'RDNT',
#  'SYK',
#  'PCRX',
#  'ILMN',
#  'ISRG',
#  'PODD',
#  'CAH',
#  'DVA',
#  'AMPE',
#  'REGN',
#  'VKTX',
#  'HUM',
#  'OMI',
#  'EXAS',
#  'RMD',
#  'MDXG',
#  'INCY',
#  'NVCN',
#  'GRFS',
#  'WMGI',
#  'ESPR',
#  'LH',
#  'MOH',
#  'HTGM',
#  'COO',
#  'ABEO',
#  'BLUE',
#  'CORT',
#  'XXII',
#  'AXGN',
#  'BRKR',
#  'NBIX',
#  'JAZZ',
#  'PRTA',
#  'PTLA',
#  'HAE',
#  'LMNX',
#  'TGTX',
#  'DPLO',
#  'BEAT',
#  'XON',
#  'SNY',
#  'CBAY',
#  'AVEO',
#  'SPPI',
#  'IDXX',
#  'ONCS',
#  'SRPT',
#  'SGEN',
#  'TFX',
#  'QDEL',
#  'INVA',
#  'LCI',
#  'WST',
#  'ARWR',
#  'MRNS',
#  'ALGN',
#  'AVXL',
#  'AXDX',
#  'NUVA',
#  'ADVM',
#  'BIOS',
#  'ARAY',
#  'DERM',
#  'AYTU',
#  'PRGO',
#  'PRAH',
#  'CLDX',
#  'VCEL',
#  'SENS',
#  'IQV',
#  'SGRY',
#  'AGEN',
#  'MNTA',
#  'MNKD',
#  'ICPT',
#  'MDCO',
#  'MMSI',
#  'PTN',
#  'PBYI',
#  'IRWD',
#  'VAR',
#  'SUPN',
#  'COLL',
#  'DRNA',
#  'PACB',
#  'AVDL',
#  'NLNK',
#  'CRL',
#  'LNTH',
#  'RHE',
#  'INO',
#  'STE',
#  'MDGS',
#  'ONVO',
#  'FGEN',
#  'ACHN',
#  'SNN',
#  'MRTX',
#  'ABMD',
#  'HRC',
#  'EGRX',
#  'DBVT',
#  'CRBP',
#  'MTD',
#  'BCRX',
#  'CBPO',
#  'CPHI',
#  'ICLR',
#  'DRRX',
#  'IOVA',
#  'TRXC',
#  'OSUR',
#  'NVCR',
#  'CRIS',
#  'PRTK',
#  'ELGX',
#  'AIMT',
#  'NVTA',
#  'CTLT',
#  'CUTR',
#  'RARE',
#  'CBM',
#  'MYOK',
#  'XNCR',
#  'FPRX',
#  'FLXN',
#  'CFMS',
#  'ENZ',
#  'CDXS',
#  'OTIC',
#  'CPRX',
#  'ZIOP',
#  'MDGL',
#  'GBT',
#  'AERI',
#  'SEM',
#  'KPTI',
#  'IVC',
#  'EHC',
#  'MYGN',
#  'LHCG',
#  'PIRS',
#  'ABIO',
#  'SRRA',
#  'UTHR',
#  'AMED',
#  'CHRS',
#  'CASI',
#  'GMED',
#  'VERU',
#  'ONCE',
#  'PTCT',
#  'ATNM',
#  'CSU',
#  'IART',
#  'CNAT',
#  'LXRX',
#  'ADMS',
#  'RMTI',
#  'ALKS',
#  'SBBP',
#  'ATRS',
#  'WCG',
#  'PTI',
#  'BIOC',
#  'ABUS',
#  'STML',
#  'NVRO',
#  'GEN',
#  'ADXS',
#  'FMS',
#  'RDY',
#  'CERS',
#  'ANGO',
#  'CTMX',
#  'RDUS',
#  'GWPH',
#  'MGLN',
#  'ADMP',
#  'ACRS',
#  'MD',
#  'CNCE',
#  'QTNT',
#  'ZGNX',
#  'ITCI',
#  'VIVO',
#  'CTIC',
#  'CTSO',
#  'ACOR',
#  'ALIM',
#  'GNMK',
#  'VYGR',
#  'LGND',
#  'BIO',
#  'RVNC',
#  'VBLT',
#  'BPMC',
#  'NBRV',
#  'TVTY',
#  'TECH',
#  'ATRA',
#  'GLYC',
#  'QURE',
#  'ICUI',
#  'WVE',
#  'SYBX',
#  'XLRN',
#  'LMAT',
#  'BLRX',
#  'CRMD',
#  'CMD',
#  'ADUS',
#  'CRHM',
#  'HIIQ',
#  'SIEN',
#  'ITGR',
#  'RGEN',
#  'EBS',
#  'SAGE',
#  'CALA',
#  'ARDX',
#  'ADAP',
#  'TRVN',
#  'LJPC',
#  'MLNT',
#  'VSTM',
#  'STAA',
#  'ADMA',
#  'ENTA',
#  'HBIO',
#  'NSTG',
#  'CDMO',
#  'CGIX',
#  'INGN',
#  'PEN',
#  'ANIP',
#  'GNCA',
#  'PRSC',
#  'FATE',
#  'TTOO',
#  'AMPH',
#  'CNMD',
#  'CYTK',
#  'FONR',
#  'CRY',
#  'AGIO',
#  'CO',
#  'EARS',
#  'HSKA',
#  'USPH',
#  'CARA',
#  'CMRX',
#  'TARO',
#  'NEO',
#  'MTEM',
#  'RTTR',
#  'ASMB',
#  'CHE',
#  'CDTX',
#  'MEIP',
#  'XENT',
#  'TCON',
#  'NERV',
#  'NYMX',
#  'FCSC',
#  'BLCM',
#  'RGNX',
#  'AFMD',
#  'EIGR',
#  'ATRC',
#  'SRDX',
#  'OCUL',
#  'EPZM',
#  'ADRO',
#  'PLX',
#  'CFRX',
#  'ENSG',
#  'RWLK',
#  'TBPH',
#  'PAHC',
#  'ALDX',
#  'ONTX',
#  'JAGX',
#  'CSII',
#  'RTIX',
#  'NEOG',
#  'GNMX',
#  'GALT',
#  'AUPH',
#  'NK',
#  'DFFN',
#  'VIVE',
#  'OFIX',
#  'GLMD',
#  'MDWD',
#  'ZFGN',
#  'ZSAN',
#  'CCXI',
#  'ARA',
#  'KIN',
#  'MACK',
#  'ATHX',
#  'PLXP',
#  'XOMA',
#  'NVIV',
#  'PULM',
#  'SCYX',
#  'NTRA',
#  'MBOT',
#  'APTO',
#  'SNSS',
#  'VCYT',
#  'CGEN',
#  'FOMX',
#  'MGEN',
#  'KMPH',
#  'RCKT',
#  'CLSN',
#  'OCX',
#  'CLLS',
#  'NTEC',
#  'FBIO',
#  'GLPG',
#  'AGRX',
#  'AGTC',
#  'CBIO',
#  'SPNE',
#  'IMUC',
#  'INFU',
#  'MGNX',
#  'AMEH',
#  'AXSM',
#  'HTBX',
#  'KALV',
#  'MCRB',
#  'REPH',
#  'PSTI',
#  'FVE',
#  'IBIO',
#  'VNRX',
#  'CERC',
#  'CBMG',
#  'ASND',
#  'ANIK',
#  'PRQR',
#  'UTMD',
#  'CATB',
#  'MTNB',
#  'RSLS',
#  'ZYNE',
#  'SNOA',
#  'NSPR',
#  'RDHL',
#  'SPHS',
#  'NHC',
#  'INFI',
#  'BSPM',
#  'ATOS',
#  'BIOL',
#  'MNOV',
#  'NURO',
#  'OXFD',
#  'PFNX',
#  'RVP',
#  'SNGX',
#  'CSBR',
#  'AVGR',
#  'ACHV',
#  'ALT',
#  'ANTH',
#  'CHFS',
#  'CPIX',
#  'DRIO',
#  'LIFE',
#  'LPCN',
#  'NEPT',
#  'TROV',
#  'TTNP',
#  'VTVT',
#  'FWP',
#  'ALBO',
#  'JYNT',
#  'CWBR',
#  'CYAD',
#  'AKER',
#  'ATRI',
#  'AHPI',
#  'ARCT',
#  'BLPH',
#  'BSTC',
#  'CHEK',
#  'CYCC',
#  'DRAD',
#  'EDAP',
#  'EKSO',
#  'EYES',
#  'IRMD',
#  'KTOV',
#  'NVUS',
#  'OGEN',
#  'OPNT',
#  'RGLS',
#  'SLS',
#  'SYN',
#  'TENX',
#  'TNXP',
#  'TRIB',
#  'XENE',
#  'XTNT',
#  'PRTO',
#  'VRML',
#  'ACER',
#  'SMMT',
#  'AEZS',
#  'AKTX',
#  'ALPN',
#  'AMS',
#  'APEN',
#  'ATEC',
#  'BASI',
#  'BCLI',
#  'BLFS',
#  'BMRA',
#  'BNTC',
#  'BPMX',
#  'BPTH',
#  'BVXV',
#  'CANF',
#  'CAPR',
#  'CATS',
#  'CBLI',
#  'CCM',
#  'CDMOP',
#  'CEMI',
#  'CHMA',
#  'CLBS',
#  'CLRB',
#  'CVM',
#  'CYCCP',
#  'CYTR',
#  'DARE',
#  'DVCR',
#  'DYNT',
#  'ELMD',
#  'EPIX',
#  'EVFM',
#  'EVGN',
#  'EVOK',
#  'EYEG',
#  'FCRE',
#  'GENE',
#  'ICCC',
#  'IDXG',
#  'IMMP',
#  'ISR',
#  'KMDA',
#  'KZIA',
#  'LAKE',
#  'LLIT',
#  'MESO',
#  'MICR',
#  'MLSS',
#  'MSON',
#  'MTP',
#  'MYOS',
#  'NAOV',
#  'NAVB',
#  'NBY',
#  'NMRD',
#  'NNVC',
#  'OPGN',
#  'ORMP',
#  'PDEX',
#  'PMD',
#  'PRPH',
#  'SLNO',
#  'SSKN',
#  'SSY',
#  'TRIL',
#  'VTGN',
#  'VVUS',
#  'VXRT',
#  'XBIT',
#  'XTLB',
#  'CMCSA',
#  'SIRI',
#  'CZR',
#  'F',
#  'NKE',
#  'BABA',
#  'GM',
#  'LOW',
#  'MAT',
#  'MIK',
#  'DIS',
#  ...]
